# %%
import pandas as pd

df = pd.read_csv("n_movies.csv")


def classify_type(row):
    year = str(row["year"])
    cert = str(row["certificate"])

    if "–" in year or cert.startswith("TV-"):
        return "Serie"
    else:
        return "Pelicula"


df["Tipo"] = df.apply(classify_type, axis=1)


df = df.drop(columns=["certificate"])



df.head(100)
# Out:
#                      title         year duration  \
# 0                Cobra Kai     (2018– )   30 min
# 1                The Crown     (2016– )   58 min
# 2         Better Call Saul  (2015–2022)   46 min
# 3            Devil in Ohio       (2022)  356 min
# 4   Cyberpunk: Edgerunners     (2022– )   24 min
# ..                     ...          ...      ...
# 95     I Used to Be Famous       (2022)  104 min
# 96                 Titanic       (1997)  194 min
# 97              Bridgerton     (2020– )   60 min
# 98                Sherlock  (2010–2017)   88 min
# 99                  Dexter  (2006–2013)   53 min
#
#                            genre  rating  \
# 0          Action, Comedy, Drama     8.5
# 1      Biography, Drama, History     8.7
# 2                   Crime, Drama     8.9
# 3         Drama, Horror, Mystery     5.9
# 4   Animation, Action, Adventure     8.6
# ..                           ...     ...
# 95          Comedy, Drama, Music     6.6
# 96                Drama, Romance     7.9
# 97       Drama, History, Romance     7.3
# 98         Crime, Drama, Mystery     9.1
# 99         Crime, Drama, Mystery     8.7
#
#                                           description  \
# 0   Decades after their 1984 All Valley Karate Tou...
# 1   Follows the political rivalries and romance of...
# 2   The trials and tribulations of criminal lawyer...
# 3   When a psychiatrist shelters a mysterious cult...
# 4   A Street Kid trying to survive in a technology...
# ..                                                ...
# 95  Follows Vince, a desperate former popstar who ...
# 96  A seventeen-year-old aristocrat falls in love ...
# 97  Wealth, lust, and betrayal set against the bac...
# 98  A modern update finds the famous sleuth and hi...
# 99  He's smart. He's lovable. He's Dexter Morgan, ...
#
#                                                 stars      votes      Tipo
# 0   ['Ralph Macchio, ', 'William Zabka, ', 'Courtn...    177,031     Serie
# 1   ['Claire Foy, ', 'Olivia Colman, ', 'Imelda St...    199,885     Serie
# 2   ['Bob Odenkirk, ', 'Rhea Seehorn, ', 'Jonathan...    501,384     Serie
# 3   ['Emily Deschanel, ', 'Sam Jaeger, ', 'Gerardo...      9,773     Serie
# 4   ['Zach Aguilar, ', 'Kenichiro Ohashi, ', 'Emi ...     15,413     Serie
# ..                                                ...        ...       ...
# 95  ['Eddie Sternberg', '| ', '    Stars:', 'Ed Sk...      2,633     Serie
# 96  ['James Cameron', '| ', '    Stars:', 'Leonard...  1,158,746  Pelicula
# 97  ['Nicola Coughlan, ', 'Luke Thompson, ', 'Jona...    133,119     Serie
# 98  ['Benedict Cumberbatch, ', 'Martin Freeman, ',...    913,816     Serie
# 99  ['Michael C. Hall, ', 'Jennifer Carpenter, ', ...    720,792     Serie
#
# [100 rows x 9 columns]

# %%
# Guardar el nuevo dataset con la columna 'type'
df.to_csv("n_movies_with_type.csv", index=False)

print("Dataset guardado como 'n_movies_with_type.csv'")
df2 = pd.read_csv("n_movies_with_type.csv")
df2.head(100)
# Out:
# Dataset guardado como 'n_movies_with_type.csv'
#                      title         year duration  \
# 0                Cobra Kai     (2018– )   30 min
# 1                The Crown     (2016– )   58 min
# 2         Better Call Saul  (2015–2022)   46 min
# 3            Devil in Ohio       (2022)  356 min
# 4   Cyberpunk: Edgerunners     (2022– )   24 min
# ..                     ...          ...      ...
# 95     I Used to Be Famous       (2022)  104 min
# 96                 Titanic       (1997)  194 min
# 97              Bridgerton     (2020– )   60 min
# 98                Sherlock  (2010–2017)   88 min
# 99                  Dexter  (2006–2013)   53 min
#
#                            genre  rating  \
# 0          Action, Comedy, Drama     8.5
# 1      Biography, Drama, History     8.7
# 2                   Crime, Drama     8.9
# 3         Drama, Horror, Mystery     5.9
# 4   Animation, Action, Adventure     8.6
# ..                           ...     ...
# 95          Comedy, Drama, Music     6.6
# 96                Drama, Romance     7.9
# 97       Drama, History, Romance     7.3
# 98         Crime, Drama, Mystery     9.1
# 99         Crime, Drama, Mystery     8.7
#
#                                           description  \
# 0   Decades after their 1984 All Valley Karate Tou...
# 1   Follows the political rivalries and romance of...
# 2   The trials and tribulations of criminal lawyer...
# 3   When a psychiatrist shelters a mysterious cult...
# 4   A Street Kid trying to survive in a technology...
# ..                                                ...
# 95  Follows Vince, a desperate former popstar who ...
# 96  A seventeen-year-old aristocrat falls in love ...
# 97  Wealth, lust, and betrayal set against the bac...
# 98  A modern update finds the famous sleuth and hi...
# 99  He's smart. He's lovable. He's Dexter Morgan, ...
#
#                                                 stars      votes      Tipo
# 0   ['Ralph Macchio, ', 'William Zabka, ', 'Courtn...    177,031     Serie
# 1   ['Claire Foy, ', 'Olivia Colman, ', 'Imelda St...    199,885     Serie
# 2   ['Bob Odenkirk, ', 'Rhea Seehorn, ', 'Jonathan...    501,384     Serie
# 3   ['Emily Deschanel, ', 'Sam Jaeger, ', 'Gerardo...      9,773     Serie
# 4   ['Zach Aguilar, ', 'Kenichiro Ohashi, ', 'Emi ...     15,413     Serie
# ..                                                ...        ...       ...
# 95  ['Eddie Sternberg', '| ', '    Stars:', 'Ed Sk...      2,633     Serie
# 96  ['James Cameron', '| ', '    Stars:', 'Leonard...  1,158,746  Pelicula
# 97  ['Nicola Coughlan, ', 'Luke Thompson, ', 'Jona...    133,119     Serie
# 98  ['Benedict Cumberbatch, ', 'Martin Freeman, ',...    913,816     Serie
# 99  ['Michael C. Hall, ', 'Jennifer Carpenter, ', ...    720,792     Serie
#
# [100 rows x 9 columns]

# %%
columnas_es = {
    "title": "Titulo",
    "year": "Año",
    "genre": "Genero",
    "duration": "Duracion",
    "rating": "Clasificacion",
    "description": "Descripcion",
    "stars": "Estrellas",
}
df2 = df2.rename(columns=columnas_es)

df2
# Out:
#                       Titulo          Año Duracion  \
# 0                  Cobra Kai     (2018– )   30 min
# 1                  The Crown     (2016– )   58 min
# 2           Better Call Saul  (2015–2022)   46 min
# 3              Devil in Ohio       (2022)  356 min
# 4     Cyberpunk: Edgerunners     (2022– )   24 min
# ...                      ...          ...      ...
# 9952          The Imperfects     (2022– )   45 min
# 9953        The Walking Dead  (2010–2022)   44 min
# 9954               The Crown     (2016– )   58 min
# 9955            Supernatural  (2005–2020)   44 min
# 9956           Devil in Ohio       (2022)  356 min
#
#                             Genero  Clasificacion  \
# 0            Action, Comedy, Drama            8.5
# 1        Biography, Drama, History            8.7
# 2                     Crime, Drama            8.9
# 3           Drama, Horror, Mystery            5.9
# 4     Animation, Action, Adventure            8.6
# ...                            ...            ...
# 9952      Action, Adventure, Drama            6.3
# 9953       Drama, Horror, Thriller            8.1
# 9954     Biography, Drama, History            8.7
# 9955        Drama, Fantasy, Horror            8.4
# 9956        Drama, Horror, Mystery            5.9
#
#                                             Descripcion  \
# 0     Decades after their 1984 All Valley Karate Tou...
# 1     Follows the political rivalries and romance of...
# 2     The trials and tribulations of criminal lawyer...
# 3     When a psychiatrist shelters a mysterious cult...
# 4     A Street Kid trying to survive in a technology...
# ...                                                 ...
# 9952  After an experimental gene therapy turns them ...
# 9953  Sheriff Deputy Rick Grimes wakes up from a com...
# 9954  Follows the political rivalries and romance of...
# 9955  Two brothers follow their father's footsteps a...
# 9956  When a psychiatrist shelters a mysterious cult...
#
#                                               Estrellas    votes   Tipo
# 0     ['Ralph Macchio, ', 'William Zabka, ', 'Courtn...  177,031  Serie
# 1     ['Claire Foy, ', 'Olivia Colman, ', 'Imelda St...  199,885  Serie
# 2     ['Bob Odenkirk, ', 'Rhea Seehorn, ', 'Jonathan...  501,384  Serie
# 3     ['Emily Deschanel, ', 'Sam Jaeger, ', 'Gerardo...    9,773  Serie
# 4     ['Zach Aguilar, ', 'Kenichiro Ohashi, ', 'Emi ...   15,413  Serie
# ...                                                 ...      ...    ...
# 9952  ['Morgan Taylor Campbell, ', 'Italia Ricci, ',...    3,130  Serie
# 9953  ['Andrew Lincoln, ', 'Norman Reedus, ', 'Melis...  970,067  Serie
# 9954  ['Claire Foy, ', 'Olivia Colman, ', 'Imelda St...  199,898  Serie
# 9955  ['Jared Padalecki, ', 'Jensen Ackles, ', 'Jim ...  439,601  Serie
# 9956  ['Emily Deschanel, ', 'Sam Jaeger, ', 'Gerardo...    9,786  Serie
#
# [9957 rows x 9 columns]

# %%
duplicados = df2[df2["Titulo"].duplicated(keep=False)]


duplicados = duplicados.sort_values(by="Titulo")

duplicados
# Out:
#                         Titulo          Año Duracion  \
# 9231            13 Reasons Why  (2017–2020)   58 min
# 9182            13 Reasons Why  (2017–2020)   59 min
# 9605            13 Reasons Why  (2017–2020)   59 min
# 226             13 Reasons Why  (2017–2020)   60 min
# 9057  3Below: Tales of Arcadia  (2018–2019)   22 min
# ...                        ...          ...      ...
# 9748           Young Wallander     (2020– )      NaN
# 3457           Zombieland Saga     (2018– )   24 min
# 9146           Zombieland Saga     (2018– )   24 min
# 9924                     Ófærð     (2015– )   60 min
# 48                       Ófærð     (2015– )   60 min
#
#                             Genero  Clasificacion  \
# 9231      Drama, Mystery, Thriller            5.7
# 9182      Drama, Mystery, Thriller            5.7
# 9605      Drama, Mystery, Thriller            5.1
# 226       Drama, Mystery, Thriller            7.5
# 9057  Animation, Action, Adventure            7.0
# ...                            ...            ...
# 9748         Crime, Drama, Mystery            7.3
# 3457    Animation, Comedy, Fantasy            7.1
# 9146    Animation, Comedy, Fantasy            8.4
# 9924         Crime, Drama, Mystery            8.0
# 48           Crime, Drama, Mystery            8.0
#
#                                             Descripcion  \
# 9231  After an incident at school, Clay thinks someo...
# 9182  The police question Tyler about the guns, leav...
# 9605  Clay is forced to confront his anxiety on the ...
# 226   Follows teenager Clay Jensen, in his quest to ...
# 9057  Stuart gets an unexpected visit from his ex-gi...
# ...                                                 ...
# 9748  Hemberg orders Kurt to take some time off afte...
# 3457  A young singer dies and becomes a zombie. She ...
# 9146  One month after Franchouchou's show at the Arp...
# 9924  In a remote town in Iceland, Police desperatel...
# 48    In a remote town in Iceland, Police desperatel...
#
#                                               Estrellas    votes   Tipo
# 9231  ['Russell Mulcahy', '| ', '    Stars:', 'Dylan...    1,743  Serie
# 9182  ['Russell Mulcahy', '| ', '    Stars:', 'Dylan...    1,959  Serie
# 9605  ['Michael Sucsy', '| ', '    Stars:', 'Dylan M...    1,868  Serie
# 226   ['Dylan Minnette, ', 'Katherine Langford, ', '...  289,319  Serie
# 9057  ['Johane Matte', '| ', '    Stars:', 'Tatiana ...      159  Serie
# ...                                                 ...      ...    ...
# 9748  ['Jens Jonsson', '| ', '    Stars:', 'Adam Pål...      400  Serie
# 3457  ['Rika Kinugawa, ', 'Kaede Hondo, ', 'Asami Ta...    1,204  Serie
# 9146  ['Kaede Hondo, ', 'Asami Tano, ', 'Risa Taneda...       68  Serie
# 9924  ['Ólafur Darri Ólafsson, ', 'Ilmur Kristjánsdó...   21,642  Serie
# 48    ['Ólafur Darri Ólafsson, ', 'Ilmur Kristjánsdó...   21,641  Serie
#
# [2417 rows x 9 columns]

# %%
df2 = (
    df2.sort_values(by=["Titulo", "Clasificacion"], ascending=[True, False])
      .drop_duplicates(subset="Titulo", keep="first")
)

# %%
df2["Titulo"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df2["duracion_num"] = (
    df2["Duracion"]
    .str.replace(" min", "", regex=False)
    .astype(float)
)


df2["genero_principal"] = df2["Genero"].str.split(",").str[0]

media_por_genero = (
    df2[
        (df2["Tipo"] == "Pelicula") &
        (df2["duracion_num"].notnull())
    ]
    .groupby("genero_principal")["duracion_num"]
    .mean()
)

media_global_peliculas = media_por_genero.mean()

def imputar_duracion(row):
    if row["Tipo"] == "Pelicula" and pd.isnull(row["Duracion"]):
        genero = row["genero_principal"]
        if genero in media_por_genero:
            return f"{round(media_por_genero[genero])} min"
        else:
            return f"{round(media_global_peliculas)} min"

    if row["Tipo"] == "Serie" and pd.isnull(row["Duracion"]):
        return "45 min"

    return row["Duracion"]

df2["Duracion"] = df2.apply(imputar_duracion, axis=1)


df2["duration_min"] = (
    df2["Duracion"]
    .str.replace(" min", "", regex=False)
    .astype(float)
)
df2
# Out:
#                              Titulo                    Año Duracion  \
# 6339                       #ABtalks  (2018 Podcast Series)   87 min
# 1026                         #Alive                 (2020)   98 min
# 5006  #AnneFrank - Parallel Stories                 (2019)   92 min
# 2493                       #BlackAF                 (2020)   36 min
# 5498            #FriendButMarried 2                 (2020)  100 min
# ...                             ...                    ...      ...
# 7255      É O Amor: Familia Camargo               (2021– )   45 min
# 4573                        Òlòtūré                 (2019)  106 min
# 48                            Ófærð               (2015– )   60 min
# 2406                       Órbita 9                 (2017)   95 min
# 7929                         Ówàmbé                 (2022)   75 min
#
#                         Genero  Clasificacion  \
# 6339                       NaN            9.1
# 1026     Action, Drama, Horror            6.3
# 5006            Drama, History            6.5
# 2493                    Comedy            6.7
# 5498  Biography, Comedy, Drama            6.9
# ...                        ...            ...
# 7255         Music, Reality-TV            5.3
# 4573              Crime, Drama            5.5
# 48       Crime, Drama, Mystery            8.0
# 2406    Drama, Romance, Sci-Fi            5.9
# 7929        Documentary, Short            NaN
#
#                                             Descripcion  \
# 6339  #ABtalks is an interview show hosted by Anas B...
# 1026  The rapid spread of an unknown infection has l...
# 5006  It is based on five women who did survive the ...
# 2493  A father takes an irreverent and honest approa...
# 5498  Ayudia (Mawar De Jongh) is not satisfied enoug...
# ...                                                 ...
# 7255  Surrounded by family and friends, Zeze Di Cama...
# 4573  A journalist goes undercover as a prostitute t...
# 48    In a remote town in Iceland, Police desperatel...
# 2406  Helena has lived on a spaceship since birth 20...
# 7929                                         Add a Plot
#
#                                               Estrellas   votes      Tipo  \
# 6339  ['Karen Wazen, ', 'Deema Al Asadi, ', 'Hala Ab...      15  Pelicula
# 1026  ['Il Cho', '| ', '    Stars:', 'Yoo Ah-in, ', ...  39,285     Serie
# 5006  ['Sabina Fedeli, ', 'Anna Migotto', '| ', '   ...   1,569  Pelicula
# 2493  ['Rashida Jones, ', 'Kenya Barris, ', 'Iman Be...   4,887     Serie
# 5498  ['Rako Prijanto', '| ', '    Stars:', 'Adipati...     317     Serie
# ...                                                 ...     ...       ...
# 7255           ['Wanessa Camargo, ', 'Zezé di Camargo']      45     Serie
# 4573  ['Kenneth Gyang', '| ', '    Stars:', 'Ada Ame...     810     Serie
# 48    ['Ólafur Darri Ólafsson, ', 'Ilmur Kristjánsdó...  21,641     Serie
# 2406  ['Hatem Khraiche', '| ', '    Stars:', 'Clara ...   7,830     Serie
# 7929                               ['Tobi Kyeremateng']     NaN  Pelicula
#
#       duracion_num genero_principal  duration_min
# 6339           NaN              NaN          87.0
# 1026          98.0           Action          98.0
# 5006          92.0            Drama          92.0
# 2493          36.0           Comedy          36.0
# 5498         100.0        Biography         100.0
# ...            ...              ...           ...
# 7255           NaN            Music          45.0
# 4573         106.0            Crime         106.0
# 48            60.0            Crime          60.0
# 2406          95.0            Drama          95.0
# 7929           NaN      Documentary          75.0
#
# [7912 rows x 12 columns]

# %%
df2 = df2[df2["Clasificacion"].notnull()]

df2["Clasificacion"].isnull().sum()
# Out:
# np.int64(0)

# %%
df2.to_csv("movies_final.csv", index=False)

print("Dataset guardado como 'movies_final.csv'")
# Out:
# Dataset guardado como 'movies_final.csv'

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import urllib.parse
import time
from tqdm import tqdm


INPUT_CSV = "movies_final.csv"
OUTPUT_CSV = "movies_with_images.csv"

TMDB_API_KEY = "6ce29e5b1926e1456f60ce528aaa9f51"

PLACEHOLDER_IMAGE = "https://upload.wikimedia.org/wikipedia/commons/a/ac/No_image_available.svg"

HEADERS = {
    "User-Agent": "Mozilla/5.0",
    "Accept-Language": "es-ES,es;q=0.9,en;q=0.8"
}

TMDB_IMAGE_BASE = "https://image.tmdb.org/t/p/w500"

# Wikipedia 
def wikipedia_image(search_term):
    try:
        query = urllib.parse.quote(search_term)
        url = f"https://en.wikipedia.org/wiki/{query}"

        r = requests.get(url, headers=HEADERS, timeout=5)
        if r.status_code != 200:
            return None

        soup = BeautifulSoup(r.text, "html.parser")
        infobox = soup.find("table", class_="infobox")

        if not infobox:
            return None

        img = infobox.find("img")
        if not img or not img.get("src"):
            return None

        src = img["src"].lower()

        if src.endswith(".svg") or "no_image_available" in src:
            return None

        return "https:" + img["src"]

    except:
        return None

# TMDB 
def tmdb_image(search_term):
    try:
        search_url = "https://api.themoviedb.org/3/search/movie"
        params = {
            "api_key": TMDB_API_KEY,
            "query": search_term,
            "language": "es-ES"
        }

        r = requests.get(search_url, params=params, timeout=5)
        if r.status_code != 200:
            return None

        data = r.json()
        if not data["results"]:
            return None

        movie = data["results"][0]
        poster_path = movie.get("poster_path")

        if not poster_path:
            return None

        return TMDB_IMAGE_BASE + poster_path

    except:
        return None



df = pd.read_csv(INPUT_CSV)

if "link" not in df.columns:
    df["link"] = ""

# Buscar imágenes
titles = df["Titulo"].unique()

print(f"🎬 Buscando imágenes de {len(titles)} películas...")

for title in tqdm(titles):
    img = wikipedia_image(title)

    if img is None:
        img = tmdb_image(title)

    if img is None:
        img = PLACEHOLDER_IMAGE

    df.loc[df["Titulo"] == title, "link"] = img

    time.sleep(0.25)

# -----------------------------
# Guardar CSV
# -----------------------------
df.to_csv(OUTPUT_CSV, index=False)
print("✅ CSV generado correctamente:", OUTPUT_CSV)
# Out:
# 🎬 Buscando imágenes de 6878 películas...
# 100%|████████████████████████████████████████████████████████████████████████████| 6878/6878 [2:30:58<00:00,  1.32s/it]
# ✅ CSV generado correctamente: movies_with_images.csv
